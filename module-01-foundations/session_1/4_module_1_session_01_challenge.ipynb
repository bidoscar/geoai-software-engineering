# %% [markdown]
# # Module 1 · Session 1 — Challenge
# ## Build and Version a Small Project Independently
#
# Complete this **without using the solutions notebook**.
#
# Create a new project called `environment-observer` using PowerShell, VS Code and Git.

# %% [markdown]
# ## Task 1 — Workstation and location
# Verify Python and Git. Navigate to a suitable parent folder. Record the commands you used and explain what each check proves.

# %% [markdown]
# **Commands and explanation:**

# %% [markdown]
# ## Task 2 — Project creation
# Create `environment-observer`, move into it, open it in VS Code, and create:
#
# - `README.md`
# - `observation.py`
# - `.gitignore`
#
# `observation.py` should print a short environmental observation, for example a location and temperature.

# %% [markdown]
# ## Task 3 — Initialise and inspect
# Initialise Git. Before staging anything:
# - inspect status;
# - identify which files are untracked;
# - explain why they are not yet in repository history.

# %% [markdown]
# **Evidence / explanation:**

# %% [markdown]
# ## Task 4 — Create two meaningful commits
# Do not commit everything in one snapshot.
#
# Suggested structure:
# 1. commit the initial Python program and README;
# 2. commit the `.gitignore` or a meaningful improvement separately.
#
# Use `git log --oneline` to verify both commits.

# %% [markdown]
# ## Task 5 — Demonstrate the three-state model
# Modify `observation.py`.
#
# Before staging:
# - run `git status`;
# - run `git diff`.
#
# Then stage the file and inspect status again.
#
# Explain where the change exists at each stage.

# %% [markdown]
# **Your explanation:**

# %% [markdown]
# ## Task 6 — Branch and remote
# Ensure the branch is named `main`. Inspect remotes. Create an empty GitHub repository, add it as `origin`, and push the local history.
#
# Record the commands used, replacing any private repository URL with `<repository-url>` in your submitted notes.

# %% [markdown]
# **Commands:**

# %% [markdown]
# ## Task 7 — Final audit
# Your final evidence should show:
# - clean working tree;
# - `main` branch;
# - at least two meaningful commits;
# - configured `origin`;
# - successful remote push.
#
# ### Reflection
# Why is this workflow important for a future GeoAI project containing code, notebooks, spatial data-processing scripts and models?

# %% [markdown]
# **Reflection:**
