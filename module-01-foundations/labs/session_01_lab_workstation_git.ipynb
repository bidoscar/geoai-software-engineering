# %% [markdown]
# # Session 01 Lab — Engineering Workstation & Git
# **Module 1 — Foundations of GeoAI Engineering**
#
# This notebook records the guided practical completed in Session 1. Most commands below are **PowerShell/Git commands** and should be run in the VS Code terminal.
#
# ## Outcomes
# - Diagnose Python, Git and VS Code.
# - Investigate command resolution and PATH.
# - Navigate/create directories.
# - Execute Python from the terminal.
# - Initialise, inspect, stage and commit with Git.
# - Configure `.gitignore`.
# - Connect `origin` and push to GitHub.

# %% [markdown]
# ## 1. Diagnose the workstation
# Run in PowerShell:
# ```powershell
# python --version
# git --version
# code --version
# pwd
# ```
# **Reflection:** Why diagnose the existing environment before reinstalling tools?

# %% [markdown]
# ## 2. Investigate command resolution
# ```powershell
# where.exe python
# where.exe code
# where.exe git
# Get-Command python
# Get-Command code
# Get-Command git
# ```
# `python` is the program/command; `--version` is an option. Windows must resolve the command to an executable. `PATH` is one important part of that process.
#
# Record where Python and VS Code were found and what changed after Git was installed.

# %% [markdown]
# ## 3. Navigate the filesystem
# ```powershell
# pwd
# ls
# cd Documents
# pwd
# cd ..
# cd .
# mkdir geoai-software-engineering
# cd geoai-software-engineering
# pwd
# code .
# ```
# Remember: `.` = current directory; `..` = parent directory.
#
# **Explain:** What does `code .` mean?

# %% [markdown]
# ## 4. Execute a Python source file
# Create `hello_geoai.py`:
# ```python
# print("GeoAI Software Engineering")
# print("Module 1 - Foundations")
# print("Environment successfully configured")
# print("My first GeoAI engineering repository is running")
# ```
# Run:
# ```powershell
# python hello_geoai.py
# ```
# **Explain:** Which component actually executes the instructions?

# %% [markdown]
# ## 5. Initialise Git
# ```powershell
# git status
# git init
# git status
# ls -Force
# ```
# Observe what changed and identify `.git`.

# %% [markdown]
# ## 6. Working directory → staging → repository
# ```text
# WORKING DIRECTORY
#       | git add
#       v
# STAGING AREA
#       | git commit
#       v
# REPOSITORY HISTORY
# ```
# Try:
# ```powershell
# git status
# git add hello_geoai.py
# git status
# git commit -m "Set up GeoAI training repository"
# git log --oneline
# ```
# **Reflection:** Why is staging useful instead of automatically committing every modified file?

# %% [markdown]
# ## 7. Inspect modifications
# Modify `hello_geoai.py`, then:
# ```powershell
# git status
# git diff
# ```
# If the pager displays `(END)`, press `q`.
#
# Observe what `+` communicates. Then stage and commit the intentional change.

# %% [markdown]
# ## 8. Add `.gitignore`
# Use:
# ```text
# __pycache__/
# *.pyc
# .venv/
# .env
# ```
# Inspect, stage and commit it.
#
# **Rule:** Never commit passwords, API keys or private credentials.

# %% [markdown]
# ## 9. Connect GitHub
# ```powershell
# git branch -M main
# git remote add origin <YOUR-REPOSITORY-URL>
# git remote -v
# git push -u origin main
# git branch -vv
# git status
# ```
# Explain the difference between `main`, `origin`, `origin/main`, `commit`, and `push`.

# %% [markdown]
# ## 10. Completion check
# ```text
# write/edit → inspect → stage → commit → local history → push → GitHub
# ```
# Evidence: Python runs; Git history exists; `.gitignore` is committed; `origin` is configured; `main` tracks `origin/main`; important work is pushed; working tree is clean.
