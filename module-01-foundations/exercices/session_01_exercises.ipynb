# %% [markdown]
# # Session 01 Exercises — Computing, Terminal & Git
# Answer in new Markdown cells without searching first.

# %% [markdown]
# ## 1 — Python and VS Code
# 1. What is the difference between Python and VS Code?
# 2. Which component ultimately executes a `.py` file?
# 3. Why can VS Code potentially work with different Python interpreters?

# %% [markdown]
# ## 2 — Commands
# For `python --version`, explain `python`, `--version`, how Windows locates the executable, and what happens if it cannot resolve the command.

# %% [markdown]
# ## 3 — Filesystem reasoning
# Explain `.`, `..`, `cd ..`, `code .`, and `mkdir geoai-software-engineering` in plain English.

# %% [markdown]
# ## 4 — Diagnose the mistake
# Why are `cd.` and `cd .` not necessarily equivalent? What does this teach about commands and arguments?

# %% [markdown]
# ## 5 — Git states
# Identify the state:
# - Changed `analysis.py`, not staged.
# - Ran `git add analysis.py`, not committed.
# - Committed the staged version.
#
# Choose: working directory / staging area / repository history.

# %% [markdown]
# ## 6 — Why staging?
# You changed `flood_model.py` (bug fix), `map.py` (visual improvement), and `README.md` (typo). Why might you avoid putting all three into one commit?

# %% [markdown]
# ## 7 — `git diff`
# What does `git diff` show? What does a line prefixed by `+` normally communicate?

# %% [markdown]
# ## 8 — `.gitignore`
# Which would you normally ignore, and why?
# - `analysis.py`
# - `.venv/`
# - `__pycache__/`
# - `README.md`
# - `.env`
# - a 20 GB satellite raster
# - `tests/test_validation.py`

# %% [markdown]
# ## 9 — Local vs remote
# Explain `main`, `origin`, and `origin/main`. Why are `git commit` and `git push` different?

# %% [markdown]
# ## 10 — Workflow
# Without looking back, write your normal sequence after editing files when you want to save and publish a coherent change.
#
# Self-assess each concept: **Green / Amber / Red**.
